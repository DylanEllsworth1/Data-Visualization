# %% [markdown]
# # CS 4304 - Assignment 1
#
# Dylan Ellsworth
#
# 201329133
#
# September 20, 2021

# %% [markdown]
# ### Question 1: Write that finds the number of unique fields of study

# %% [markdown]
# We import pandas and then open our students file, downloaded from D2L. I then decided to show some info on the dataframe, so it was easier to glance at for later questions.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6221 entries, 0 to 6220
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   REF_DATE                                                    6221 non-null   object
#  1   GEO                                                         6221 non-null   object
#  2   Institution type                                            6221 non-null   object
#  3   Registration status                                         6221 non-null   object
#  4   International Standard Classification of Education (ISCED)  6221 non-null   object
#  5   Field of study                                              6221 non-null   object
#  6   Gender                                                      6221 non-null   object
# ...

# %%
df['Field of study'].nunique()
# Out:
# 14

# %% [markdown]
# ### Question 2: List all the unique degree types in the International Standard Classification of Education(ISCED) field.

# %% [markdown]
# An array showing the different degree types.

# %%
df['International Standard Classification of Education (ISCED)'].unique()
# Out:
# array(["Bachelor's or equivalent", "Master's or equivalent",
#        'Doctoral or equivalent', 'Post-secondary non-tertiary education',
#        'Short-cycle tertiary education',
#        'Not applicable, International Standard Classification of Education (ISCED)',
#        'Upper secondary education'], dtype=object)

# %% [markdown]
# ### Question 3: Determine the number of entries in the data set that have institution type of University or College

# %% [markdown]
# We have 6221 students in either Univeristy or College, equal to the total number of rows. Therefore, every data entry is a student enrolled in either University or College.

# %%
df[df['Institution type'].str.contains('University')| df['Institution type'].str.contains('College')]
# Out:
#        REF_DATE                        GEO Institution type  \
# 0     2018/2019  Newfoundland and Labrador       University
# 1     2018/2019  Newfoundland and Labrador       University
# 2     2018/2019  Newfoundland and Labrador       University
# 3     2018/2019  Newfoundland and Labrador       University
# 4     2018/2019  Newfoundland and Labrador       University
# ...         ...                        ...              ...
# 6216  2018/2019                Territories          College
# 6217  2018/2019                Territories          College
# 6218  2018/2019                Territories          College
# 6219  2018/2019                Territories          College
# 6220  2018/2019                Territories          College
#
#      Registration status  \
# 0      Full-time student
# 1      Full-time student
# 2      Full-time student
# 3      Full-time student
# 4      Full-time student
# ...                  ...
# 6216   Part-time student
# 6217   Part-time student
# ...

# %% [markdown]
# ###  Question 4: Compute the total number of students enrolled in Newfoundland and Labrador

# %% [markdown]
# There are 347 students enrolled in Newfoundland and Labrador

# %%
df[df['GEO']== 'Newfoundland and Labrador']
# Out:
#       REF_DATE                        GEO Institution type  \
# 0    2018/2019  Newfoundland and Labrador       University
# 1    2018/2019  Newfoundland and Labrador       University
# 2    2018/2019  Newfoundland and Labrador       University
# 3    2018/2019  Newfoundland and Labrador       University
# 4    2018/2019  Newfoundland and Labrador       University
# ..         ...                        ...              ...
# 342  2018/2019  Newfoundland and Labrador          College
# 343  2018/2019  Newfoundland and Labrador          College
# 344  2018/2019  Newfoundland and Labrador          College
# 345  2018/2019  Newfoundland and Labrador          College
# 346  2018/2019  Newfoundland and Labrador          College
#
#     Registration status  \
# 0     Full-time student
# 1     Full-time student
# 2     Full-time student
# 3     Full-time student
# 4     Full-time student
# ..                  ...
# 342   Part-time student
# 343   Part-time student
# 344   Part-time student
# ...

# %% [markdown]
# ### Question 5: Compute the number of female and number of male students enrolled at Memorial University of Newfoundland

# %% [markdown]
# We create a new dataframe for our mun students

# %%
df2 = df[df['Institution type'].str.contains('University') & df['GEO'].str.contains('Newfoundland and Labrador')]
df2
# Out:
#       REF_DATE                        GEO Institution type  \
# 0    2018/2019  Newfoundland and Labrador       University
# 1    2018/2019  Newfoundland and Labrador       University
# 2    2018/2019  Newfoundland and Labrador       University
# 3    2018/2019  Newfoundland and Labrador       University
# 4    2018/2019  Newfoundland and Labrador       University
# ..         ...                        ...              ...
# 234  2018/2019  Newfoundland and Labrador       University
# 235  2018/2019  Newfoundland and Labrador       University
# 236  2018/2019  Newfoundland and Labrador       University
# 237  2018/2019  Newfoundland and Labrador       University
# 238  2018/2019  Newfoundland and Labrador       University
#
#     Registration status  \
# 0     Full-time student
# 1     Full-time student
# 2     Full-time student
# 3     Full-time student
# 4     Full-time student
# ..                  ...
# 234   Part-time student
# 235   Part-time student
# 236   Part-time student
# ...

# %% [markdown]
# Now we just need the value counts for each male and female on our new data frame.

# %%
df2['Gender'].value_counts()
# Out:
# Male gender       113
# Female gender     108
# Gender unknown     18
# Name: Gender, dtype: int64
